# %%
import pandas as pd
import streamlit as st
from app.connection.get_data import get_data

# %%
# Ejemplo de consulta sobre la tabla de monthly REPORT
query = 'SELECT * FROM [monthly_report]'
df = get_data(query)
df
# Out:
# Connection established
# /Users/luciano/Documents/Cursos Dev/SoyHenry/DTS-08/Labs/PG/PF_DS/app/connection/get_data.py:23: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, cnxn)
#        license_class  trips_per_day  farebox_per_day  unique_drivers  \
# 0    FHV - Black Car           5359                0            2737
# 1    FHV - Black Car           6213                0            2640
# 2    FHV - Black Car           5338                0            2921
# 3    FHV - Black Car          10060                0            5237
# 4    FHV - Black Car           7681                0            4561
# ..               ...            ...              ...             ...
# 648           Yellow         101328          1918370            9678
# 649           Yellow         105740          2100507           10242
# 650           Yellow         118027          2293014           10730
# 651           Yellow         108146          2088897           10804
# 652           Yellow         109290          2358924           10749
#
#      unique_vehicles  vehicles_per_day  avg_days_vehicles_on_road  \
# 0               2725              1469                       16.7
# 1               2620              1618                       17.3
# 2               2882              1296                       13.9
# 3               5225              2653                       15.2
# 4               4550              2055                       14.0
# ..               ...               ...                        ...
# 648             7169              5823                       25.2
# 649             7373              6000                       24.4
# 650             7576              6437                       26.3
# 651             7685              6100                       23.8
# 652             7791              6529                       26.0
#
#      avg_hours_per_day_per_vehicle  avg_days_drivers_on_road  \
# 0                              3.3                      16.7
# 1                              3.5                      17.2
# 2                              3.3                      13.6
# 3                              3.3                      15.2
# 4                              3.2                      14.0
# ..                             ...                       ...
# 648                            8.8                      21.6
# 649                            8.9                      20.4
# 650                            9.2                      21.9
# 651                            9.1                      19.9
# 652                            8.7                      22.0
#
#      avg_hours_per_day_per_driver  ...  month_date  farebox_per_month  week  \
# 0                             3.3  ...  2015-01-28                  0     4
# 1                             3.5  ...  2015-02-28                  0     8
# 2                             3.3  ...  2015-03-28                  0    12
# 3                             3.2  ...  2015-04-28                  0    17
# 4                             3.2  ...  2015-05-28                  0    21
# ..                            ...  ...         ...                ...   ...
# 648                           7.6  ...  2022-08-28           59469470    34
# 649                           7.6  ...  2022-09-28           63015210    39
# 650                           7.8  ...  2022-10-28           71083434    43
# 651                           7.7  ...  2022-11-28           62666910    48
# 652                           7.5  ...  2022-12-28           73126644    52
#
#     trips_per_week  year  farebox_per_week total_trips_per_day  \
# 0            37513  2015                 0                5359
# 1            43491  2015                 0                6213
# 2            37366  2015                 0                5338
# 3            70420  2015                 0               10060
# 4            53767  2015                 0                7681
# ..             ...   ...               ...                 ...
# 648         709296  2022          13428590              101328
# 649         740180  2022          14703549              105740
# 650         826189  2022          16051098              118027
# 651         757022  2022          14622279              108146
# 652         765030  2022          16512468              109290
#
#      shared_trips_per_day_percent  farebox_per_trip  farebox_per_vehicle
# 0                             0.0          0.000000             0.000000
# 1                             0.0          0.000000             0.000000
# 2                             0.0          0.000000             0.000000
# 3                             0.0          0.000000             0.000000
# 4                             0.0          0.000000             0.000000
# ..                            ...               ...                  ...
# 648                           0.0         18.932279          8295.364765
# 649                           0.0         19.864829          8546.753018
# 650                           0.0         19.427877          9382.713041
# 651                           0.0         19.315527          8154.445023
# 652                           0.0         21.584079          9386.040816
#
# [653 rows x 26 columns]
